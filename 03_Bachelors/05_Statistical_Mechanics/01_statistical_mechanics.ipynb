# %% [markdown]
# # Statistical Mechanics
#
# > **How to use this notebook:** Read each section, understand the concept, then write the code yourself in the empty cell below. Use the hints as a guide — not a solution.
#
# ---

# %%
# Run this cell first — imports you'll likely need
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from scipy import constants          # physical constants
# from scipy.integrate import solve_ivp  # ODE solver
# from scipy.fft import fft, fftfreq      # Fourier transform
# from sympy import *                      # symbolic math
# import seaborn as sns                    # statistical plots

plt.rcParams['figure.dpi'] = 120
plt.rcParams['font.size'] = 12

# %% [markdown]
# ## Boltzmann Entropy — Counting Microstates
#
# For N=100 coin flips, compute Ω(n) = C(N,n) (binomial coefficient) for n = 0 to N. Plot Ω vs n and S = k_B ln(Ω) vs n. Show entropy is maximum at n=N/2 (most probable macrostate).
#
# **Hints:**
# - from scipy.special import comb
# - n = np.arange(0, N+1)
# - Omega = comb(N, n, exact=False)
# - S = constants.k * np.log(Omega + 1e-300)  # avoid log(0)
# - Mark n=N/2 as the equilibrium state

# %%
# Your code here

# %% [markdown]
# ## The Three Quantum Statistics
#
# Plot the occupation number n(E) for Maxwell-Boltzmann, Bose-Einstein, and Fermi-Dirac statistics at T=300K, with μ=0:
# - MB: exp(-E/kT)
# - BE: 1/(exp(E/kT) - 1)
# - FD: 1/(exp(E/kT) + 1)
#
# **Hints:**
# - E = np.linspace(0.001, 0.5, 500)  # in eV
# - kT = constants.k * T / constants.e  # in eV
# - n_MB = np.exp(-E/kT)
# - n_BE = 1/(np.exp(E/kT) - 1)
# - n_FD = 1/(np.exp(E/kT) + 1)

# %%
# Your code here

# %% [markdown]
# ## Fermi-Dirac at Different Temperatures
#
# Plot the Fermi-Dirac distribution for copper (E_F = 7.04 eV) at T=0, 300K, 3000K, 10000K. Show how the distribution broadens around E_F. Compute the fraction of electrons excited above E_F.
#
# **Hints:**
# - E = np.linspace(0, 14, 1000)  # eV
# - E_F = 7.04  # eV for copper
# - For each T: f = 1/(np.exp((E-E_F)/(kT)) + 1)  # handle T=0 with np.where
# - Excited fraction: np.trapz(f[E>E_F], E[E>E_F]) / np.trapz(f, E)

# %%
# Your code here

# %% [markdown]
# ## Ising Model — Monte Carlo Simulation
#
# The 2D Ising model has spins ±1 on a square lattice. Energy: E = -J Σ sᵢsⱼ. Use the Metropolis algorithm to simulate at different temperatures. Plot magnetization M = ⟨Σs⟩/N² vs T to see the phase transition at T_c ≈ 2.27 J/k_B.
#
# **Hints:**
# - N = 20  # 20×20 lattice
# - spins = np.random.choice([-1, 1], (N,N))
# - Metropolis step: flip random spin, compute ΔE, accept if ΔE<0 or rand < exp(-ΔE/kT)
# - Run many steps; measure ⟨|M|⟩ at each T
# - Plot |M| vs T — sharp drop near T_c shows phase transition

# %%
# Your code here
