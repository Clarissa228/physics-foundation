# %% [markdown]
# # Solid State Physics
#
# > **How to use this notebook:** Read each section, understand the concept, then write the code yourself in the empty cell below. Use the hints as a guide — not a solution.
#
# ---

# %%
# Run this cell first — imports you'll likely need
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from scipy import constants          # physical constants
# from scipy.integrate import solve_ivp  # ODE solver
# from scipy.fft import fft, fftfreq      # Fourier transform
# from sympy import *                      # symbolic math
# import seaborn as sns                    # statistical plots

plt.rcParams['figure.dpi'] = 120
plt.rcParams['font.size'] = 12

# %% [markdown]
# ## Crystal Lattices
#
# Plot 2D Bravais lattices: square, rectangular, hexagonal, oblique. Then visualise an FCC and BCC unit cell in 3D. Mark the basis vectors.
#
# **Hints:**
# - For square: a1=[a,0], a2=[0,a]; generate points with np.meshgrid
# - Plot lattice points as dots; draw basis vectors with plt.quiver
# - For 3D FCC: corner atoms at (0,0,0) and face centres at (a/2,a/2,0) etc.
# - Use ax.scatter() for atoms; ax.plot() for unit cell edges

# %%
# Your code here

# %% [markdown]
# ## Bragg Diffraction Pattern
#
# Bragg's law: 2d sinθ = nλ. For a crystal with d-spacing 2.82 Å (NaCl) and X-rays λ=1.54 Å (Cu Kα), find all Bragg angles. Simulate a powder diffraction pattern: intensity vs 2θ.
#
# **Hints:**
# - d_spacings = [2.82, 1.99, 1.63, ...]  # for different hkl planes
# - For each d: theta = arcsin(n*lam/(2*d))
# - Plot as peaks: plt.vlines(2*theta_degrees, 0, intensity)
# - Gaussian-broaden peaks for realism

# %%
# Your code here

# %% [markdown]
# ## Free Electron Model — Density of States
#
# For a 3D free electron gas: g(E) = (V/2π²)(2m/ℏ²)^(3/2) √E. Plot g(E) vs E. Mark the Fermi energy E_F for copper (8.5e28 electrons/m³). Compute and plot the Fermi-Dirac weighted density of states n(E)·f(E) at 300K.
#
# **Hints:**
# - E = np.linspace(0, 15, 1000)  # eV
# - g_E = C * np.sqrt(E)  # C = (V/2pi²)(2m/hbar²)^1.5
# - f_FD = 1/(np.exp((E-E_F)/kT) + 1)
# - n_occupied = g_E * f_FD
# - E_F for Cu: from n = integral of g(E) up to E_F

# %%
# Your code here

# %% [markdown]
# ## Band Structure — Nearly Free Electron Model
#
# Near the Brillouin zone boundary (k = π/a), the free electron parabola E=ℏ²k²/2m splits into two bands separated by the band gap 2|V_G|. Plot the band structure in the reduced zone scheme.
#
# **Hints:**
# - k = np.linspace(-np.pi/a, np.pi/a, 500)  # first Brillouin zone
# - Free electron: E = hbar²k²/(2*m)
# - Near zone boundary: E± = E_free ± |V_G|  # simplified version
# - Plot both branches; shade the band gap
# - Label valence band and conduction band

# %%
# Your code here
