# %% [markdown]
# # Nuclear and Particle Physics
#
# > **How to use this notebook:** Read each section, understand the concept, then write the code yourself in the empty cell below. Use the hints as a guide — not a solution.
#
# ---

# %%
# Run this cell first — imports you'll likely need
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from scipy import constants          # physical constants
# from scipy.integrate import solve_ivp  # ODE solver
# from scipy.fft import fft, fftfreq      # Fourier transform
# from sympy import *                      # symbolic math
# import seaborn as sns                    # statistical plots

plt.rcParams['figure.dpi'] = 120
plt.rcParams['font.size'] = 12

# %% [markdown]
# ## Binding Energy Curve — Bethe-Weizsäcker Formula
#
# Plot BE/A vs A using the liquid drop formula with constants a_v=15.85, a_s=18.34, a_c=0.71, a_a=23.21, a_p=11.2 MeV. Compare with real data for a few nuclei. Mark the fission and fusion regions.
#
# **Hints:**
# - A = np.arange(2, 250)
# - Z = np.round(A/2).astype(int)  # rough approximation
# - delta = a_p/np.sqrt(A)  # pairing term (for even-even nuclei)
# - BE = a_v*A - a_s*A**(2/3) - a_c*Z*(Z-1)/A**(1/3) - a_a*(A-2*Z)**2/A - delta
# - Plot BE/A vs A; mark Fe-56 as peak, U-235 for fission, H-2 for fusion

# %%
# Your code here

# %% [markdown]
# ## Radioactive Decay Chain
#
# Simulate the U-238 decay chain. Each isotope decays to the next with a given half-life. Set up the Bateman equations (system of ODEs) and solve with solve_ivp. Plot population of each isotope vs time.
#
# **Hints:**
# - half_lives = [4.47e9, 24.1, 1.17, ...]  # years and days — convert to seconds
# - def decay_chain(t, N): dN[0] = -lambda[0]*N[0]; dN[i] = lambda[i-1]*N[i-1] - lambda[i]*N[i]
# - sol = solve_ivp(decay_chain, [0, T_max], N0, max_step=...)
# - Plot each population — most daughters reach secular equilibrium

# %%
# Your code here

# %% [markdown]
# ## Standard Model — Particle Table
#
# Create a visual table of the Standard Model particles using matplotlib: 3 generations of quarks and leptons, plus gauge bosons. Use colored boxes with particle names, masses, and charges.
#
# **Hints:**
# - Use fig, ax = plt.subplots(figsize=(12,8))
# - Draw colored rectangles with ax.add_patch(Rectangle(...))
# - Color code: quarks=purple, leptons=green, bosons=red, Higgs=yellow
# - Add text for each particle: name, mass in MeV, charge

# %%
# Your code here

# %% [markdown]
# ## Nuclear Fission vs Fusion — Q-Value
#
# Compute the Q-value (energy released) for:
# 1. U-235 fission: U-235 + n → Ba-141 + Kr-92 + 3n
# 2. D-T fusion: D + T → He-4 + n
# Using mass excess values. Show how much energy per kg of fuel each releases.
#
# **Hints:**
# - Use atomic mass data (mass excess in MeV)
# - Q = (sum of initial masses - sum of final masses)*c^2
# - Convert to MeV and then to Joules
# - Energy per kg: Q[J] / (fuel_mass_kg)
# - Compare with: coal (~30 MJ/kg), fission (~80e9 MJ/kg), fusion (~340e9 MJ/kg)

# %%
# Your code here
