# %% [markdown]
# # Classical Electrodynamics
#
# > **How to use this notebook:** Read each section, understand the concept, then write the code yourself in the empty cell below. Use the hints as a guide — not a solution.
#
# ---

# %%
# Run this cell first — imports you'll likely need
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from scipy import constants          # physical constants
# from scipy.integrate import solve_ivp  # ODE solver
# from scipy.fft import fft, fftfreq      # Fourier transform
# from sympy import *                      # symbolic math
# import seaborn as sns                    # statistical plots

plt.rcParams['figure.dpi'] = 120
plt.rcParams['font.size'] = 12

# %% [markdown]
# ## Verify Maxwell's Equations for a Plane Wave
#
# For E⃗ = E₀cos(kx-ωt)ŷ, B⃗ = B₀cos(kx-ωt)ẑ, verify all 4 Maxwell equations using SymPy:
# ∇·E=0, ∇·B=0, ∇×E=-∂B/∂t, ∇×B=μ₀ε₀∂E/∂t
#
# **Hints:**
# - from sympy import symbols, cos, diff, simplify, Matrix
# - Define E and B as symbolic expressions
# - Compute all curls and divergences
# - Verify each equation simplifies to 0 = 0

# %%
# Your code here

# %% [markdown]
# ## Dipole Radiation Pattern
#
# An oscillating electric dipole radiates power ∝ sin²θ (donut pattern). Plot this radiation pattern in 3D as a surface where r = sin²θ.
#
# **Hints:**
# - theta = np.linspace(0, np.pi, 100)
# - phi = np.linspace(0, 2*np.pi, 100)
# - r = np.sin(theta)**2
# - x = r*sin(theta)*cos(phi); y = r*sin(theta)*sin(phi); z = r*cos(theta)
# - ax.plot_surface(X, Y, Z, cmap='plasma')

# %%
# Your code here

# %% [markdown]
# ## Fresnel Coefficients — Reflection and Transmission
#
# Plot the Fresnel reflection coefficients r_s and r_p vs incident angle θᵢ (0 to 90°) for an air-glass interface (n₁=1, n₂=1.5). Show Brewster's angle where r_p=0.
#
# **Hints:**
# - theta_i = np.linspace(0, np.pi/2, 300)
# - theta_t = np.arcsin(n1*np.sin(theta_i)/n2)  # Snell's law
# - r_s = (n1*cos_i - n2*cos_t)/(n1*cos_i + n2*cos_t)
# - r_p = (n2*cos_i - n1*cos_t)/(n2*cos_i + n1*cos_t)
# - theta_B = np.arctan(n2/n1)  # Brewster's angle

# %%
# Your code here

# %% [markdown]
# ## Skin Depth in a Conductor
#
# An EM wave penetrating a conductor is attenuated as e^(-x/δ) where δ = √(2/μωσ) is the skin depth. Plot δ vs frequency for copper (σ=5.8e7 S/m). Show that at microwave frequencies, δ is micrometres.
#
# **Hints:**
# - f = np.logspace(0, 12, 500)  # 1 Hz to 1 THz
# - omega = 2*np.pi*f
# - delta = np.sqrt(2/(mu0*omega*sigma))
# - plt.loglog(f, delta*1e6, label='Skin depth (μm)')
# - Mark household current (50Hz), radio (MHz), microwave (GHz)

# %%
# Your code here
