# %% [markdown]
# # Special Relativity
#
# > **How to use this notebook:** Read each section, understand the concept, then write the code yourself in the empty cell below. Use the hints as a guide — not a solution.
#
# ---

# %%
# Run this cell first — imports you'll likely need
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from scipy import constants          # physical constants
# from scipy.integrate import solve_ivp  # ODE solver
# from scipy.fft import fft, fftfreq      # Fourier transform
# from sympy import *                      # symbolic math
# import seaborn as sns                    # statistical plots

plt.rcParams['figure.dpi'] = 120
plt.rcParams['font.size'] = 12

# %% [markdown]
# ## Lorentz Factor γ vs Velocity
#
# γ = 1/√(1-v²/c²). Plot γ vs v/c from 0 to 0.9999c. Show that γ→∞ as v→c. Also plot the relativistic momentum p=γmv and kinetic energy KE=γmc²-mc² vs v/c.
#
# **Hints:**
# - v_over_c = np.linspace(0, 0.9999, 10000)
# - gamma = 1/np.sqrt(1 - v_over_c**2)
# - Plot on linear scale; then zoom in near v/c=1
# - Mark notable speeds: 0.1c, 0.5c, 0.9c, 0.99c with their γ values

# %%
# Your code here

# %% [markdown]
# ## Spacetime Diagram (Minkowski Diagram)
#
# Draw a spacetime diagram (x vs ct). Plot: the worldline of a stationary observer, a moving observer (v=0.6c), and the light cone. Show that events inside the light cone are causally connected.
#
# **Hints:**
# - Draw x-axis and ct-axis
# - Stationary worldline: vertical line at x=0
# - Moving worldline: line with slope c/v (in ct vs x)
# - Light cone: two 45° lines (ct = ±x)
# - Shade the timelike region (inside cone) and spacelike region (outside)

# %%
# Your code here

# %% [markdown]
# ## Time Dilation and Length Contraction
#
# Proper time Δτ = Δt/γ. Proper length L₀ → L = L₀/γ. Plot Δτ/Δt and L/L₀ vs v/c on the same graph. Show that at v=0.866c, γ=2 so time is dilated by factor 2 and length contracted by factor 2.
#
# **Hints:**
# - v_over_c = np.linspace(0, 0.999, 1000)
# - gamma = 1/np.sqrt(1 - v_over_c**2)
# - time_dilation = 1/gamma; length_contraction = 1/gamma
# - plt.plot(v_over_c, time_dilation, label='Δτ/Δt')
# - Mark v/c = 0.866 where γ=2

# %%
# Your code here

# %% [markdown]
# ## E² = (pc)² + (mc²)² — The Relativistic Energy-Momentum Relation
#
# Plot E vs p for: photon (m=0, so E=pc), electron, and proton. Show that at low p, E≈mc²+p²/2m (non-relativistic), and at high p, E≈pc (ultra-relativistic). All curves on one log-log plot.
#
# **Hints:**
# - p = np.logspace(-30, -16, 1000)  # kg·m/s
# - m_e = 9.11e-31; m_p = 1.67e-27
# - E_electron = np.sqrt((p*c)**2 + (m_e*c**2)**2)
# - E_photon = p*c
# - Compare with non-relativistic E_NR = m_e*c**2 + p**2/(2*m_e)

# %%
# Your code here
