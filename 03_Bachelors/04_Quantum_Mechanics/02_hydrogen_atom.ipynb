# %% [markdown]
# # Hydrogen Atom
#
# > **How to use this notebook:** Read each section, understand the concept, then write the code yourself in the empty cell below. Use the hints as a guide — not a solution.
#
# ---

# %%
# Run this cell first — imports you'll likely need
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from scipy import constants          # physical constants
# from scipy.integrate import solve_ivp  # ODE solver
# from scipy.fft import fft, fftfreq      # Fourier transform
# from sympy import *                      # symbolic math
# import seaborn as sns                    # statistical plots

plt.rcParams['figure.dpi'] = 120
plt.rcParams['font.size'] = 12

# %% [markdown]
# ## Radial Wavefunctions
#
# The hydrogen radial wavefunctions Rₙₗ(r) involve associated Laguerre polynomials. Plot R₁₀, R₂₀, R₂₁, R₃₀, R₃₁, R₃₂ vs r (in Bohr radii a₀). Also plot r²|Rₙₗ|² (radial probability density).
#
# **Hints:**
# - from scipy.special import assoc_laguerre, factorial
# - a0 = 0.529e-10  # Bohr radius
# - r = np.linspace(0, 30*a0, 1000)
# - Look up the formula for R_nl or use hydrogen_wavefunction libraries
# - Note: r²|R|² shows the most probable radius — for 1s it's at a₀

# %%
# Your code here

# %% [markdown]
# ## 2D Probability Density Maps
#
# Plot |ψ_nlm(r,θ,φ)|² as a 2D cross-section (in the xz-plane, φ=0) for:
# (1,0,0): 1s — spherically symmetric
# (2,1,0): 2p₀ — dumbbell shape
# (3,2,0): 3d — more complex
#
# **Hints:**
# - x = np.linspace(-20, 20, 300)  # in Bohr radii
# - Z, X = np.meshgrid(x, x); R = np.sqrt(X**2+Z**2); Theta = np.arctan2(X, Z)
# - Compute |psi(R, Theta, phi=0)|² using R_nl * Y_lm
# - plt.imshow(psi2, cmap='hot', origin='lower')

# %%
# Your code here

# %% [markdown]
# ## Emission Spectrum
#
# Compute all transition wavelengths for n_upper = 1 to 6 → n_lower = 1 to 5 (Lyman, Balmer, Paschen, Brackett, Pfund). Plot as vertical colored lines on a wavelength axis.
#
# **Hints:**
# - R_H = 1.097e7  # Rydberg constant
# - For each (n1, n2) pair where n2 > n1:
# - 1/lambda = R_H * (1/n1**2 - 1/n2**2)
# - Assign color by series: Lyman=UV, Balmer=visible, Paschen=IR
# - Use plt.vlines(lam, 0, 1) for each line

# %%
# Your code here

# %% [markdown]
# ## Zeeman Effect — Splitting in a Magnetic Field
#
# In a magnetic field B, energy levels split: ΔE = m_l μ_B B where μ_B = 9.274e-24 J/T. For the 2p→1s transition (l=1→l=0), show the split lines. Plot energy levels without and with B.
#
# **Hints:**
# - For 1s: m_l = 0 only
# - For 2p: m_l = -1, 0, +1
# - With B=1T: delta_E = m_l * mu_B * B in eV
# - Draw energy level diagrams side by side; draw transition arrows
# - Compute wavelength shifts in nm

# %%
# Your code here
