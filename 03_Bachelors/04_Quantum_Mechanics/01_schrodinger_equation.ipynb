# %% [markdown]
# # Quantum Mechanics — Schrödinger Equation
#
# > **How to use this notebook:** Read each section, understand the concept, then write the code yourself in the empty cell below. Use the hints as a guide — not a solution.
#
# ---

# %%
# Run this cell first — imports you'll likely need
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from scipy import constants          # physical constants
# from scipy.integrate import solve_ivp  # ODE solver
# from scipy.fft import fft, fftfreq      # Fourier transform
# from sympy import *                      # symbolic math
# import seaborn as sns                    # statistical plots

plt.rcParams['figure.dpi'] = 120
plt.rcParams['font.size'] = 12

# %% [markdown]
# ## Infinite Square Well — Wavefunctions
#
# Solve the TISE in a box [0, L]: ψₙ(x) = √(2/L) sin(nπx/L), Eₙ = n²π²ℏ²/2mL². Plot ψₙ and |ψₙ|² for n=1,2,3,4,5. Verify orthonormality: ∫ψₙψₘdx = δₙₘ.
#
# **Hints:**
# - x = np.linspace(0, L, 1000)  # L = 1e-10 m (1 Angstrom box)
# - psi_n = np.sqrt(2/L) * np.sin(n*np.pi*x/L)
# - Plot psi_n (wavefunction) and |psi_n|² (probability density)
# - Use np.trapz to verify orthonormality numerically

# %%
# Your code here

# %% [markdown]
# ## Quantum Harmonic Oscillator
#
# Wavefunctions: ψₙ(x) = Cₙ Hₙ(x/x₀) exp(-x²/2x₀²) where Hₙ are Hermite polynomials and x₀=√(ℏ/mω). Plot ψₙ for n=0,1,2,3 with the classical turning points and the V(x) = ½mω²x² potential.
#
# **Hints:**
# - from scipy.special import hermite
# - x0 = np.sqrt(hbar/(m*omega))
# - H_n = hermite(n); psi = H_n(x/x0)*np.exp(-x**2/(2*x0**2))
# - Normalise with np.trapz; plot alongside V(x)
# - Mark classical turning points where E_n = V(x)

# %%
# Your code here

# %% [markdown]
# ## Quantum Tunnelling
#
# For a particle with energy E < V₀ hitting a rectangular barrier of height V₀ and width L, the transmission coefficient is:
# T = 1/(1 + (V₀² sinh²(κL))/(4E(V₀-E)))
# where κ = √(2m(V₀-E))/ℏ. Plot T vs E/V₀ and T vs barrier width L.
#
# **Hints:**
# - E_over_V0 = np.linspace(0.01, 0.99, 300)
# - kappa = np.sqrt(2*m*V0*(1-E_over_V0))/hbar
# - T = 1/(1 + (V0**2*np.sinh(kappa*L)**2)/(4*V0*E_over_V0*(V0-V0*E_over_V0)))
# - Also plot T vs L for fixed E=0.5*V0 — shows exponential decay

# %%
# Your code here

# %% [markdown]
# ## Time Evolution of a Gaussian Wave Packet
#
# A Gaussian wave packet spreads over time due to dispersion. ψ(x,0) = exp(-x²/4σ²)exp(ik₀x). The width grows as σ(t) = σ√(1+(ℏt/2mσ²)²). Animate the probability density |ψ(x,t)|².
#
# **Hints:**
# - x = np.linspace(-20, 20, 1000)  # in units of sigma
# - For each t: compute psi(x,t) using the Fourier transform method
# - Or use the analytic formula for Gaussian spread
# - Plot |psi|² for t=0, 1, 5, 10 (in natural units)

# %%
# Your code here
