# %% [markdown]
# # Normal Modes and Vibrations
#
# > **How to use this notebook:** Read each section, understand the concept, then write the code yourself in the empty cell below. Use the hints as a guide — not a solution.
#
# ---

# %%
# Run this cell first — imports you'll likely need
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from scipy import constants          # physical constants
# from scipy.integrate import solve_ivp  # ODE solver
# from scipy.fft import fft, fftfreq      # Fourier transform
# from sympy import *                      # symbolic math
# import seaborn as sns                    # statistical plots

plt.rcParams['figure.dpi'] = 120
plt.rcParams['font.size'] = 12

# %% [markdown]
# ## Two Coupled Oscillators
#
# Masses m₁=m₂=m connected to walls and to each other by springs k. Find normal mode frequencies: ω₁=√(k/m) (symmetric), ω₂=√(3k/m) (antisymmetric). Verify with eigenvalue calculation.
#
# **Hints:**
# - K = np.array([[2*k, -k],[-k, 2*k]])  # stiffness matrix
# - M = np.diag([m, m])  # mass matrix
# - eigenvalues, eigenvectors = np.linalg.eig(np.linalg.inv(M) @ K)
# - omega = np.sqrt(eigenvalues); plot each normal mode

# %%
# Your code here

# %% [markdown]
# ## N Coupled Oscillators — Phonon Dispersion
#
# For a chain of N masses with nearest-neighbour spring coupling, the dispersion relation is ω(k) = 2√(K/m)|sin(ka/2)|. Plot ω vs k from 0 to π/a. This is the acoustic phonon branch.
#
# **Hints:**
# - k_vals = np.linspace(0, np.pi/a, 300)
# - omega = 2*np.sqrt(K/m)*np.abs(np.sin(k_vals*a/2))
# - Plot ω vs k; label the Brillouin zone boundary at k = π/a
# - This is the foundation for understanding sound in solids

# %%
# Your code here

# %% [markdown]
# ## Vibrating String — Normal Modes
#
# Solve the 1D wave equation ∂²u/∂t² = v²∂²u/∂x² with fixed ends using separation of variables. Normal modes: uₙ(x,t) = sin(nπx/L)cos(nωt). Plot modes n=1,2,3,4,5.
#
# **Hints:**
# - x = np.linspace(0, L, 300)
# - For n = 1, 2, 3, 4, 5: u = np.sin(n*np.pi*x/L)
# - Plot all 5 on same axes with vertical offset for clarity
# - Label nodes (zeros) for each mode

# %%
# Your code here
