# %% [markdown]
# # Simple Harmonic Motion
#
# > **How to use this notebook:** Read each section, understand the concept, then write the code yourself in the empty cell below. Use the hints as a guide — not a solution.
#
# ---

# %%
# Run this cell first — imports you'll likely need
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from scipy import constants          # physical constants
# from scipy.integrate import solve_ivp  # ODE solver
# from scipy.fft import fft, fftfreq      # Fourier transform
# from sympy import *                      # symbolic math
# import seaborn as sns                    # statistical plots

plt.rcParams['figure.dpi'] = 120
plt.rcParams['font.size'] = 12

# %% [markdown]
# ## SHM: Displacement, Velocity, Acceleration
#
# For SHM: x(t) = A cos(ωt + φ)
#   v(t) = -Aω sin(ωt + φ)
#   a(t) = -Aω² cos(ωt + φ)
#
# Plot all three on the same figure for A=0.1 m, ω=2π rad/s, φ=0. Notice the phase relationships.
#
# **Hints:**
# - t = np.linspace(0, 2, 500)  # 2 seconds
# - x = A * np.cos(omega*t + phi)
# - Use three subplots with shared x-axis: plt.subplots(3,1, sharex=True)
# - Mark T = 2π/ω with a vertical dashed line

# %%
# Your code here

# %% [markdown]
# ## Energy in SHM
#
# KE = ½mv², PE = ½kx², Total E = ½kA²
# Plot all three vs time and vs position. The total should be constant. Also plot the phase space (v vs x) — it should be an ellipse.
#
# **Hints:**
# - KE = 0.5*m*v**2; PE = 0.5*k*x**2; E = KE + PE
# - Plot KE, PE, E vs t on one subplot
# - Plot v vs x on another — should trace an ellipse
# - Mark the turning points where KE=0

# %%
# Your code here

# %% [markdown]
# ## Damped Oscillations
#
# With damping coefficient b: ẍ + (b/m)ẋ + (k/m)x = 0
# The solution is x(t) = A·e^(-γt)·cos(ω_d·t) where γ=b/2m, ω_d=√(ω₀²-γ²)
#
# Plot for underdamped (γ < ω₀), critically damped (γ = ω₀), and overdamped (γ > ω₀).
#
# **Hints:**
# - Solve ODE with solve_ivp for each damping case
# - Or use the analytic solution directly
# - All three on the same plot with different colors
# - Mark the envelope ±A·e^(-γt) for the underdamped case

# %%
# Your code here

# %% [markdown]
# ## Resonance — Amplitude vs Driving Frequency
#
# A driven damped oscillator has steady-state amplitude: A(ω) = F₀/m / √((ω₀²-ω²)² + (bω/m)²)
#
# Plot A vs ω/ω₀ for several values of damping b. Show that the resonance peak sharpens as damping decreases (higher Q factor).
#
# **Hints:**
# - omega = np.linspace(0, 3*omega0, 1000)
# - A = (F0/m) / np.sqrt((omega0**2 - omega**2)**2 + (b*omega/m)**2)
# - Plot for b = 0.1, 0.5, 1.0, 2.0
# - Mark ω = ω₀ with a vertical dashed line

# %%
# Your code here
