# %% [markdown]
# # Wave Motion
#
# > **How to use this notebook:** Read each section, understand the concept, then write the code yourself in the empty cell below. Use the hints as a guide — not a solution.
#
# ---

# %%
# Run this cell first — imports you'll likely need
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from scipy import constants          # physical constants
# from scipy.integrate import solve_ivp  # ODE solver
# from scipy.fft import fft, fftfreq      # Fourier transform
# from sympy import *                      # symbolic math
# import seaborn as sns                    # statistical plots

plt.rcParams['figure.dpi'] = 120
plt.rcParams['font.size'] = 12

# %% [markdown]
# ## Travelling Wave — Snapshot and Animation
#
# A sinusoidal wave: y(x,t) = A sin(kx - ωt)
# Plot snapshots of this wave at t=0, T/4, T/2, 3T/4, T on the same graph. Then animate it using matplotlib.animation.
#
# **Hints:**
# - A=0.1, k=2*np.pi/1.0 (wavelength λ=1m), omega=2*np.pi (f=1Hz)
# - x = np.linspace(0, 5, 500)
# - Plot y at 5 different time values
# - For animation: from matplotlib.animation import FuncAnimation

# %%
# Your code here

# %% [markdown]
# ## Standing Waves — Nodes and Antinodes
#
# A standing wave forms when two identical waves travel in opposite directions:
# y₁ = A sin(kx - ωt), y₂ = A sin(kx + ωt)
# y_standing = 2A sin(kx) cos(ωt)
#
# Plot the standing wave at several times. Mark nodes (where amplitude = 0 always) and antinodes.
#
# **Hints:**
# - y_standing = 2*A*np.sin(k*x)*np.cos(omega*t) for several t
# - Nodes: where sin(kx) = 0 → x = nλ/2
# - Antinodes: where |sin(kx)| = 1 → x = (2n+1)λ/4
# - Use plt.axvline() to mark nodes

# %%
# Your code here

# %% [markdown]
# ## Beats
#
# Two waves with slightly different frequencies f₁ and f₂ superpose to produce beats at frequency |f₁ - f₂|. Plot the superposition and show the beat envelope.
#
# **Hints:**
# - y1 = A*np.sin(2*np.pi*f1*t); y2 = A*np.sin(2*np.pi*f2*t)
# - y_sum = y1 + y2
# - Envelope: 2A*cos(π*(f1-f2)*t) — overlay as dashed line
# - Try f1=440 Hz (A4), f2=444 Hz → 4 beats/sec

# %%
# Your code here

# %% [markdown]
# ## Fourier Synthesis — Building a Square Wave
#
# Any periodic wave can be built from sine harmonics. A square wave = (4/π)[sin(x) + sin(3x)/3 + sin(5x)/5 + ...]. Add harmonics one by one and see how the shape converges.
#
# **Hints:**
# - x = np.linspace(0, 4*np.pi, 1000)
# - Start with n=1 term; add n=3, 5, 7, ... up to 51
# - Plot each partial sum overlaid on the target square wave
# - Use different alphas to show progression

# %%
# Your code here
