# %% [markdown]
# # Kinetic Theory of Gases
#
# > **How to use this notebook:** Read each section, understand the concept, then write the code yourself in the empty cell below. Use the hints as a guide — not a solution.
#
# ---

# %%
# Run this cell first — imports you'll likely need
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from scipy import constants          # physical constants
# from scipy.integrate import solve_ivp  # ODE solver
# from scipy.fft import fft, fftfreq      # Fourier transform
# from sympy import *                      # symbolic math
# import seaborn as sns                    # statistical plots

plt.rcParams['figure.dpi'] = 120
plt.rcParams['font.size'] = 12

# %% [markdown]
# ## Maxwell-Boltzmann Speed Distribution
#
# The Maxwell-Boltzmann distribution of molecular speeds:
# f(v) = 4π(m/2πkT)^(3/2) · v² · exp(-mv²/2kT)
#
# Plot f(v) for N₂ at T = 100K, 300K, 1000K on the same graph. Mark the most probable speed (v_mp), mean speed (v_avg), and rms speed (v_rms).
#
# **Hints:**
# - v = np.linspace(0, 2000, 1000)  # m/s
# - m = 28 * 1.66e-27  # mass of N2 molecule in kg
# - f = 4*np.pi*(m/(2*np.pi*k*T))**1.5 * v**2 * np.exp(-m*v**2/(2*k*T))
# - v_mp = sqrt(2kT/m), v_avg = sqrt(8kT/πm), v_rms = sqrt(3kT/m)

# %%
# Your code here

# %% [markdown]
# ## 2D Ideal Gas Simulation
#
# Simulate N=50 particles in a 2D box. Give each a random position and velocity drawn from the Maxwell-Boltzmann distribution. Bounce particles off walls elastically. Plot the positions of all particles at one snapshot.
#
# **Hints:**
# - positions: np.random.uniform(0, L, (N, 2))
# - speeds from MB: use np.random.rayleigh() as approximation
# - For wall bounces: if x < 0 or x > L: vx *= -1
# - plt.scatter(pos[:,0], pos[:,1], s=10)

# %%
# Your code here

# %% [markdown]
# ## Van der Waals Equation — Phase Transitions
#
# The van der Waals equation: (P + a/V²)(V - b) = RT
# Plot P-V isotherms for T below, at, and above the critical temperature T_c = 8a/(27Rb). Compare with ideal gas P = RT/V.
#
# **Hints:**
# - Solve for P: P = RT/(V-b) - a/V**2
# - Plot for T = 0.8*Tc, 1.0*Tc, 1.2*Tc
# - The S-shaped curve below T_c indicates liquid-gas coexistence
# - Mark the Maxwell construction (equal areas) for T < T_c

# %%
# Your code here

# %% [markdown]
# ## Mean Free Path vs Pressure and Temperature
#
# Mean free path: λ = kT / (√2 π d² P)
# where d is molecular diameter (~3×10⁻¹⁰ m for air). Plot λ vs P (at fixed T=300K) and λ vs T (at fixed P=1 atm).
#
# **Hints:**
# - P = np.logspace(-3, 5, 200) * 101325  # Pa, from 0.001 to 100000 atm
# - lam = k*T / (np.sqrt(2) * np.pi * d**2 * P)
# - Use plt.semilogx() for the pressure plot
# - Annotate where λ equals the size of a room, a bacterium, an atom

# %%
# Your code here
