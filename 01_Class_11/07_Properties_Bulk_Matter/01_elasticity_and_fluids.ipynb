# %% [markdown]
# # Properties of Bulk Matter — Elasticity & Fluids
#
# > **How to use this notebook:** Read each section, understand the concept, then write the code yourself in the empty cell below. Use the hints as a guide — not a solution.
#
# ---

# %%
# Run this cell first — imports you'll likely need
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from scipy import constants          # physical constants
# from scipy.integrate import solve_ivp  # ODE solver
# from scipy.fft import fft, fftfreq      # Fourier transform
# from sympy import *                      # symbolic math
# import seaborn as sns                    # statistical plots

plt.rcParams['figure.dpi'] = 120
plt.rcParams['font.size'] = 12

# %% [markdown]
# ## Stress-Strain Curve
#
# Plot a typical stress-strain curve for a metal showing: elastic region (linear, slope = Young's modulus E), yield point, plastic region, and fracture point. Mark all key regions.
#
# **Hints:**
# - Use piecewise numpy arrays to define the curve shape
# - Region 1: σ = E·ε (linear, elastic)
# - Region 2: plateau after yield, then rising
# - Region 3: necking and fracture
# - Use plt.fill_betweenx() to shade the elastic region

# %%
# Your code here

# %% [markdown]
# ## Fluid Pressure and Archimedes' Principle
#
# Plot pressure vs depth in water (P = ρgh). Then compute the buoyant force on an object of volume V and density ρ_obj submerged in water. What fraction is submerged if it floats?
#
# **Hints:**
# - P = rho_water * g * h for h in np.linspace(0, 100, 200)
# - Fraction submerged = ρ_obj / ρ_fluid (from equilibrium of forces)
# - Plot for several materials: ice, wood, steel, aluminium

# %%
# Your code here

# %% [markdown]
# ## Poiseuille Flow — Velocity Profile
#
# In a circular pipe of radius R, the velocity profile for viscous flow is parabolic:
# v(r) = (P₁-P₂)/(4ηL) × (R² - r²)
#
# Plot this profile as a 2D cross-section (use imshow or contourf on a disk).
#
# **Hints:**
# - r = np.linspace(0, R, 200)
# - v = (dP / (4*eta*L)) * (R**2 - r**2)
# - For 2D: use meshgrid and set v=0 outside disk
# - plt.contourf() with a colormap like 'coolwarm'

# %%
# Your code here

# %% [markdown]
# ## Capillary Rise and Surface Tension
#
# Height of capillary rise: h = 2T cosθ / (ρgr). Plot h vs tube radius r for water (T=0.072 N/m, θ=0°) and mercury (T=0.485 N/m, θ=140°). Notice mercury is depressed!
#
# **Hints:**
# - r = np.linspace(0.1e-3, 5e-3, 200)  # 0.1 mm to 5 mm
# - h_water = 2*T_water*cos(theta_water)/(rho*g*r)
# - h_mercury will be negative (depression)
# - plt.axhline(0, color='k') to mark the baseline

# %%
# Your code here
