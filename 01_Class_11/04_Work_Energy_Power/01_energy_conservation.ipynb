# %% [markdown]
# # Work, Energy & Power
#
# > **How to use this notebook:** Read each section, understand the concept, then write the code yourself in the empty cell below. Use the hints as a guide — not a solution.
#
# ---

# %%
# Run this cell first — imports you'll likely need
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from scipy import constants          # physical constants
# from scipy.integrate import solve_ivp  # ODE solver
# from scipy.fft import fft, fftfreq      # Fourier transform
# from sympy import *                      # symbolic math
# import seaborn as sns                    # statistical plots

plt.rcParams['figure.dpi'] = 120
plt.rcParams['font.size'] = 12

# %% [markdown]
# ## Work-Energy Theorem on a Spring
#
# A mass m=2 kg on a spring (k=50 N/m) starts at x=0.5 m from equilibrium. Plot KE = ½mv², PE = ½kx², and total mechanical energy E = KE + PE vs time. The total should be constant.
#
# **Hints:**
# - x(t) = A*cos(ωt), ω = sqrt(k/m)
# - v(t) = -Aω*sin(ωt)
# - Compute KE and PE at each time step
# - Use plt.plot() for all three on same axes — total should be flat

# %%
# Your code here

# %% [markdown]
# ## Elastic and Inelastic Collisions
#
# Simulate 1D collisions between two objects. For elastic: KE is conserved. For perfectly inelastic: objects stick together. Compute and display momentum and KE before and after. Verify conservation laws.
#
# **Hints:**
# - For elastic: solve using conservation of momentum and KE → two equations, two unknowns
# - For inelastic: v_final = (m1*v1 + m2*v2)/(m1+m2)
# - Create a bar chart comparing KE before and after for both cases

# %%
# Your code here

# %% [markdown]
# ## Potential Energy Curves and Equilibrium
#
# Plot U(x) for three potentials: (1) spring U=½kx², (2) gravitational U=-GMm/r, (3) Lennard-Jones U=4ε[(σ/r)¹²-(σ/r)⁶]. Mark equilibrium points where dU/dx = 0. Which equilibria are stable vs unstable?
#
# **Hints:**
# - Use np.gradient() to compute F = -dU/dx numerically
# - Mark equilibrium with plt.axvline() or plt.scatter()
# - For Lennard-Jones: use ε=1, σ=1 and plot for r in [0.9, 3]

# %%
# Your code here

# %% [markdown]
# ## Bouncing Ball — Energy Decay
#
# A ball dropped from height h₀ bounces with coefficient of restitution e (0<e<1), so each bounce height is hₙ = e² × hₙ₋₁. Plot the height of each bounce vs bounce number. How many bounces until height < 1cm?
#
# **Hints:**
# - heights = [h0 * e**(2*n) for n in range(N)]
# - plt.stem() makes a nice bounce plot
# - Find N such that heights[N] < 0.01 using np.argmax(np.array(heights) < 0.01)

# %%
# Your code here
