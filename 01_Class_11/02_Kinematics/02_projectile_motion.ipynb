# %% [markdown]
# # Projectile Motion
#
# > **How to use this notebook:** Read each section, understand the concept, then write the code yourself in the empty cell below. Use the hints as a guide — not a solution.
#
# ---

# %%
# Run this cell first — imports you'll likely need
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from scipy import constants          # physical constants
# from scipy.integrate import solve_ivp  # ODE solver
# from scipy.fft import fft, fftfreq      # Fourier transform
# from sympy import *                      # symbolic math
# import seaborn as sns                    # statistical plots

plt.rcParams['figure.dpi'] = 120
plt.rcParams['font.size'] = 12

# %% [markdown]
# ## Symbolic Derivation with SymPy
#
# Derive the projectile equations symbolically: x(t), y(t), range R, maximum height H, and time of flight T. Let SymPy do the algebra for you.
#
# **Hints:**
# - from sympy import symbols, cos, sin, solve, simplify
# - Define symbols: u, theta, g, t = symbols(...)
# - Integrate acceleration to get velocity, then position
# - Use solve() to find time when y=0 (range)

# %%
# Your code here

# %% [markdown]
# ## Trajectory for Multiple Angles
#
# Plot the projectile trajectory y(x) for launch angles of 15°, 30°, 45°, 60°, 75° with the same initial speed (e.g., 50 m/s). All on one plot.
#
# **Hints:**
# - angles = np.radians([15, 30, 45, 60, 75])
# - For each angle: compute x(t), y(t) arrays, then plot y vs x
# - Stop trajectory when y < 0 (ground level)
# - Mark the landing point for each

# %%
# Your code here

# %% [markdown]
# ## Effect of Air Resistance
#
# With air drag: a_x = -k*v_x, a_y = -g - k*v_y where k is a drag coefficient. Use scipy.integrate.solve_ivp to solve this system of ODEs. Compare with the no-drag case on the same plot.
#
# **Hints:**
# - Define state vector [x, y, vx, vy]
# - def equations(t, state): return [vx, vy, -k*vx, -g - k*vy]
# - sol = solve_ivp(equations, [0, T], state0)
# - Try k = 0.1, 0.3 and compare with k = 0

# %%
# Your code here

# %% [markdown]
# ## Range vs Angle — Find the Optimum
#
# Plot the range R as a function of launch angle θ (0° to 90°). Where is the maximum? Does it change with initial speed? Does it change with gravity (try Moon: g=1.62)?
#
# **Hints:**
# - Compute R = u²sin(2θ)/g for each angle
# - Use plt.axvline(45) to mark the theoretical optimum
# - Overlay curves for different values of g

# %%
# Your code here
