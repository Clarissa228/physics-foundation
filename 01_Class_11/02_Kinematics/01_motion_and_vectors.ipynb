# %% [markdown]
# # Motion in a Straight Line & Vectors
#
# > **How to use this notebook:** Read each section, understand the concept, then write the code yourself in the empty cell below. Use the hints as a guide — not a solution.
#
# ---

# %%
# Run this cell first — imports you'll likely need
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from scipy import constants          # physical constants
# from scipy.integrate import solve_ivp  # ODE solver
# from scipy.fft import fft, fftfreq      # Fourier transform
# from sympy import *                      # symbolic math
# import seaborn as sns                    # statistical plots

plt.rcParams['figure.dpi'] = 120
plt.rcParams['font.size'] = 12

# %% [markdown]
# ## Vectors: Operations and Visualization
#
# Represent 2D and 3D vectors as numpy arrays. Implement and visualize: addition, subtraction, dot product, cross product, magnitude, and unit vectors.
#
# **Hints:**
# - np.array([x, y]) for 2D vectors
# - np.dot(a, b) and np.cross(a, b)
# - Use plt.quiver() to draw vectors
# - np.linalg.norm(v) for magnitude

# %%
# Your code here

# %% [markdown]
# ## SUVAT Equations — Position, Velocity, Acceleration
#
# The equations of motion for constant acceleration:
# - v = u + at
# - s = ut + ½at²
# - v² = u² + 2as
#
# Plot s(t), v(t), and a(t) on subplots for a freely falling body (u=0, a=9.8 m/s²). Try different initial velocities.
#
# **Hints:**
# - Create t = np.linspace(0, 5, 300)
# - Compute s, v for each t
# - Use fig, axes = plt.subplots(3,1) for three panels
# - Label axes with units (m, m/s, m/s²)

# %%
# Your code here

# %% [markdown]
# ## Relative Motion
#
# Two cars A and B move in the same direction. Car A: u=20 m/s, a=0. Car B starts 50 m behind: u=10 m/s, a=2 m/s². Plot position of both vs time on same graph. When does B overtake A?
#
# **Hints:**
# - Find overtaking time: solve s_A = s_B analytically or use np.where()
# - Mark the crossing point on the plot with plt.scatter()
# - Plot relative velocity (v_A - v_B) on a second subplot

# %%
# Your code here
