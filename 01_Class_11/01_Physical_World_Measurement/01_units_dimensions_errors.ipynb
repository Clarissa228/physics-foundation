# %% [markdown]
# # Units, Dimensions & Error Analysis
#
# > **How to use this notebook:** Read each section, understand the concept, then write the code yourself in the empty cell below. Use the hints as a guide — not a solution.
#
# ---

# %%
# Run this cell first — imports you'll likely need
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from scipy import constants          # physical constants
# from scipy.integrate import solve_ivp  # ODE solver
# from scipy.fft import fft, fftfreq      # Fourier transform
# from sympy import *                      # symbolic math
# import seaborn as sns                    # statistical plots

plt.rcParams['figure.dpi'] = 120
plt.rcParams['font.size'] = 12

# %% [markdown]
# ## Dimensional Analysis with SymPy
#
# Every physical formula must be dimensionally consistent. Use SymPy to define the dimensions [M], [L], [T] and verify that equations like v² = u² + 2as are dimensionally correct.
#
# **Hints:**
# - Define symbols for M, L, T using sympy.symbols()
# - Check that both sides of an equation have the same dimensions
# - Try verifying F = ma, E = mc², and P = mv² on your own

# %%
# Your code here

# %% [markdown]
# ## Error Propagation (Analytical)
#
# If z = f(x, y), the uncertainty in z due to uncertainties dx and dy follows:
# - For z = x + y: dz = sqrt(dx² + dy²)
# - For z = x*y: dz/z = sqrt((dx/x)² + (dy/y)²)
# - For z = xⁿ: dz/z = |n| * dx/x
#
# Write functions that compute propagated error for each case.
#
# **Hints:**
# - def add_error(x, dx, y, dy): ...
# - def mul_error(x, dx, y, dy): ...
# - def power_error(x, dx, n): ...

# %%
# Your code here

# %% [markdown]
# ## Monte Carlo Error Propagation
#
# Instead of analytical propagation, you can estimate error by running many simulations with random noise. Generate 10000 measurements of x and y (drawn from Gaussian distributions), compute z = f(x, y) for each, and plot the resulting distribution of z.
#
# **Hints:**
# - Use np.random.normal(mean, std, size=10000)
# - Compute z for each sample
# - Plot histogram with plt.hist(..., bins=50, density=True)
# - Overlay the analytical Gaussian prediction

# %%
# Your code here

# %% [markdown]
# ## Law of Large Numbers
#
# As you take more measurements, the sample mean converges to the true mean. Demonstrate this for a quantity with known true value. Plot the running mean vs number of samples.
#
# **Hints:**
# - Generate samples with np.random.normal()
# - Compute cumulative mean with np.cumsum() / np.arange()
# - Plot running mean with a horizontal dashed line for the true value

# %%
# Your code here
