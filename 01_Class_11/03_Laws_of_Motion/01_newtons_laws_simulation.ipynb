# %% [markdown]
# # Newton's Laws of Motion
#
# > **How to use this notebook:** Read each section, understand the concept, then write the code yourself in the empty cell below. Use the hints as a guide — not a solution.
#
# ---

# %%
# Run this cell first — imports you'll likely need
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from scipy import constants          # physical constants
# from scipy.integrate import solve_ivp  # ODE solver
# from scipy.fft import fft, fftfreq      # Fourier transform
# from sympy import *                      # symbolic math
# import seaborn as sns                    # statistical plots

plt.rcParams['figure.dpi'] = 120
plt.rcParams['font.size'] = 12

# %% [markdown]
# ## F = ma — Force, Acceleration, Velocity, Position
#
# Apply a constant force to a 5 kg object. Plot how acceleration, velocity, and position change over time. Then try a time-varying force like F = F₀ sin(ωt).
#
# **Hints:**
# - a = F/m; v = v0 + a*t; x = x0 + v0*t + 0.5*a*t**2
# - For varying force, use cumulative integration: np.cumsum(F/m * dt)
# - Create 3 subplots: F(t), v(t), x(t)

# %%
# Your code here

# %% [markdown]
# ## Atwood Machine
#
# Two masses m₁ and m₂ hang over a frictionless pulley. The acceleration is a = (m₁-m₂)g/(m₁+m₂) and tension T = 2m₁m₂g/(m₁+m₂). Derive these using SymPy, then simulate and plot positions of both masses over time.
#
# **Hints:**
# - Define m1, m2, g as sympy symbols, solve for a and T
# - Numerically: set m1=3, m2=2, simulate using a
# - Plot y₁(t) going down and y₂(t) going up on same axes

# %%
# Your code here

# %% [markdown]
# ## Block on Inclined Plane — Friction
#
# A block of mass m sits on a plane inclined at angle θ. Gravity component along plane: mg sinθ. Friction force: μmg cosθ (opposing motion). Find the critical angle where the block starts sliding. Simulate motion after that.
#
# **Hints:**
# - Plot net force vs θ from 0 to 90°
# - Find critical angle: where mg sinθ > μmg cosθ
# - Simulate sliding with solve_ivp, plot position vs time for θ > critical

# %%
# Your code here

# %% [markdown]
# ## Circular Motion — Centripetal Force
#
# A particle moves in a circle of radius R at constant speed v. Show that the acceleration always points toward the center. Plot the circular path, velocity vectors (tangential), and acceleration vectors (centripetal) at several points.
#
# **Hints:**
# - x(t) = R*cos(ωt), y(t) = R*sin(ωt)
# - vx = -Rω*sin(ωt), vy = Rω*cos(ωt)
# - Use plt.quiver() to draw velocity and acceleration arrows
# - Verify a = v²/R numerically

# %%
# Your code here
