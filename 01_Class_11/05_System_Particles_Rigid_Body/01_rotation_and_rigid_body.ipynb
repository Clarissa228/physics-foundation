# %% [markdown]
# # System of Particles & Rigid Body Rotation
#
# > **How to use this notebook:** Read each section, understand the concept, then write the code yourself in the empty cell below. Use the hints as a guide — not a solution.
#
# ---

# %%
# Run this cell first — imports you'll likely need
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from scipy import constants          # physical constants
# from scipy.integrate import solve_ivp  # ODE solver
# from scipy.fft import fft, fftfreq      # Fourier transform
# from sympy import *                      # symbolic math
# import seaborn as sns                    # statistical plots

plt.rcParams['figure.dpi'] = 120
plt.rcParams['font.size'] = 12

# %% [markdown]
# ## Centre of Mass of a Discrete System
#
# Given N point masses at positions (xᵢ, yᵢ), the centre of mass is x_cm = Σmᵢxᵢ / Σmᵢ. Compute and plot the CM for a set of 5 masses, marking it clearly.
#
# **Hints:**
# - masses = np.array([...]); positions = np.array([[x1,y1],...])
# - x_cm = np.dot(masses, positions[:,0]) / masses.sum()
# - Plot masses as circles (size ∝ mass), mark CM with a star

# %%
# Your code here

# %% [markdown]
# ## Moment of Inertia — Numerical Integration
#
# Compute the moment of inertia I = ∫ r² dm for a uniform disk of mass M and radius R. Do it numerically: subdivide the disk into tiny area elements and sum r²·(M/Area)·dA. Compare with analytical result I = ½MR².
#
# **Hints:**
# - Use a 2D grid: x = np.linspace(-R, R, 1000)
# - Only count points inside the disk: x²+y² ≤ R²
# - Sum r²·dm for all valid points
# - Compare with 0.5*M*R**2

# %%
# Your code here

# %% [markdown]
# ## Conservation of Angular Momentum — Spinning Skater
#
# An ice skater spinning with moment of inertia I₁ and angular velocity ω₁ pulls her arms in, reducing I to I₂. Since L = Iω is conserved: ω₂ = I₁ω₁/I₂. Plot ω as a function of I as she changes arm position.
#
# **Hints:**
# - Let I vary from I_arms_out to I_arms_in (e.g., 2.0 to 0.5 kg·m²)
# - omega = L / I where L = I_initial * omega_initial
# - Plot ω vs I. Also plot rotational KE = ½Iω² — notice it increases!

# %%
# Your code here

# %% [markdown]
# ## Rolling Without Slipping
#
# A sphere and a cylinder roll down an inclined plane from height h. Velocity at bottom: v = sqrt(2gh/(1+I/(mR²))). For solid sphere: I=2mR²/5; for hollow cylinder: I=mR². Which one wins the race? Simulate and animate.
#
# **Hints:**
# - Compute v_bottom for both shapes
# - Plot position x(t) along the incline for both — use kinematics with effective g
# - Create side-by-side animation or just plot x vs t

# %%
# Your code here
