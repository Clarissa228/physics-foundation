# %% [markdown]
# # Gravitation & Orbital Mechanics
#
# > **How to use this notebook:** Read each section, understand the concept, then write the code yourself in the empty cell below. Use the hints as a guide — not a solution.
#
# ---

# %%
# Run this cell first — imports you'll likely need
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from scipy import constants          # physical constants
# from scipy.integrate import solve_ivp  # ODE solver
# from scipy.fft import fft, fftfreq      # Fourier transform
# from sympy import *                      # symbolic math
# import seaborn as sns                    # statistical plots

plt.rcParams['figure.dpi'] = 120
plt.rcParams['font.size'] = 12

# %% [markdown]
# ## Gravitational Field and Potential
#
# For a point mass M at the origin, plot the gravitational field g⃗ = -GM/r² r̂ and gravitational potential V = -GM/r in 2D. Use quiver for the field and contourf for the potential.
#
# **Hints:**
# - Create meshgrid: X, Y = np.meshgrid(np.linspace(-5,5,30), np.linspace(-5,5,30))
# - R = np.sqrt(X**2 + Y**2); avoid r=0 with np.maximum(R, 0.1)
# - gx = -G*M*X/R**3, gy = -G*M*Y/R**3
# - plt.quiver(X, Y, gx, gy) and plt.contourf(X, Y, V)

# %%
# Your code here

# %% [markdown]
# ## Simulate a Planetary Orbit
#
# The equations of motion for a planet around the Sun:
#   ẍ = -GM·x/r³,  ÿ = -GM·y/r³
#
# Use scipy.integrate.solve_ivp to solve this system. Start the Earth at perihelion and give it the correct velocity. Plot the orbit.
#
# **Hints:**
# - State vector: [x, y, vx, vy]
# - def gravity(t, s): x,y,vx,vy = s; r=sqrt(x²+y²); return [vx,vy,-GM*x/r³,-GM*y/r³]
# - Earth: x0=1.47e11 m, vy0=3.0e4 m/s, GM_sun=1.327e20
# - plt.plot(sol.y[0], sol.y[1]) for the orbit

# %%
# Your code here

# %% [markdown]
# ## Verify Kepler's Laws
#
# From your orbital simulation:
# 1. **First law**: Is the orbit elliptical? Fit an ellipse.
# 2. **Second law**: Compute the area swept in equal time intervals — are they equal?
# 3. **Third law**: Simulate orbits for different semi-major axes a. Verify T² ∝ a³.
#
# **Hints:**
# - Area swept: A = ½|r × v|·Δt — compute for several time windows
# - For T² ∝ a³: vary initial distance, measure orbital period, plot T² vs a³
# - Use np.polyfit to fit a line to log(T) vs log(a)

# %%
# Your code here

# %% [markdown]
# ## Escape Velocity vs Planet Properties
#
# v_escape = √(2GM/R). Compute and compare escape velocities for all planets in the solar system (use real data for M and R). Plot as a horizontal bar chart.
#
# **Hints:**
# - Planet data: masses and radii as numpy arrays
# - v_esc = np.sqrt(2 * G * masses / radii)
# - plt.barh(planet_names, v_esc / 1000)  # in km/s
# - Mark Earth's escape velocity with a vertical dashed line

# %%
# Your code here
