# %% [markdown]
# # Thermodynamics
#
# > **How to use this notebook:** Read each section, understand the concept, then write the code yourself in the empty cell below. Use the hints as a guide — not a solution.
#
# ---

# %%
# Run this cell first — imports you'll likely need
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from scipy import constants          # physical constants
# from scipy.integrate import solve_ivp  # ODE solver
# from scipy.fft import fft, fftfreq      # Fourier transform
# from sympy import *                      # symbolic math
# import seaborn as sns                    # statistical plots

plt.rcParams['figure.dpi'] = 120
plt.rcParams['font.size'] = 12

# %% [markdown]
# ## P-V Diagrams for Thermodynamic Processes
#
# For an ideal gas, plot the following processes on a single P-V diagram:
# - Isothermal: P = nRT/V (constant T)
# - Adiabatic: PV^γ = const (γ=5/3 for monatomic)
# - Isobaric: horizontal line
# - Isochoric: vertical line
#
# Use n=1 mol, T=300K.
#
# **Hints:**
# - V = np.linspace(0.5, 5, 300)  # in litres
# - P_iso = nRT/V; P_adi = P0*(V0/V)**gamma
# - Use different colors and a legend for each process
# - Shade the area under isothermal to show work done

# %%
# Your code here

# %% [markdown]
# ## Carnot Cycle on a P-V Diagram
#
# The Carnot cycle has 4 steps: isothermal expansion (T_H), adiabatic expansion, isothermal compression (T_C), adiabatic compression. Plot all four steps as a closed loop on a P-V diagram. Calculate the efficiency η = 1 - T_C/T_H.
#
# **Hints:**
# - Choose T_H=600K, T_C=300K
# - Step 1: P = nRT_H/V (from V1 to V2)
# - Step 2: adiabatic P∝V^(-γ) (from V2 to V3)
# - Steps 3 & 4: isothermal and adiabatic back
# - Shade the enclosed area — this represents net work done

# %%
# Your code here

# %% [markdown]
# ## Heat Engine Efficiency Comparison
#
# Plot efficiency vs hot reservoir temperature T_H (with T_C = 300K fixed) for: Carnot (ideal), Otto cycle (car engine: η = 1 - r^(1-γ) where r is compression ratio), and a simple η = 30% (typical real engine). Which comes closest to Carnot?
#
# **Hints:**
# - T_H = np.linspace(350, 1200, 300)
# - eta_carnot = 1 - T_C/T_H
# - eta_otto = 1 - r**(1-gamma) for r=8 (typical car)
# - plt.fill_between to shade gap between Carnot and Otto

# %%
# Your code here

# %% [markdown]
# ## Entropy and the Second Law
#
# For a reversible process: ΔS = Q/T. For an irreversible process: ΔS > Q/T. Plot entropy change for: (1) heat flowing from hot to cold reversibly, (2) same heat flow irreversibly. Show that total ΔS ≥ 0 always.
#
# **Hints:**
# - Reversible: delta_S_hot = -Q/T_H, delta_S_cold = +Q/T_C
# - Total delta_S_rev = Q*(1/T_C - 1/T_H) ≥ 0
# - Plot delta_S_total vs T_H for fixed Q and T_C
# - Mark T_H = T_C as the reversible limit

# %%
# Your code here
