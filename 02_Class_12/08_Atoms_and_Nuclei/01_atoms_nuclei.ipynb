# %% [markdown]
# # Atoms and Nuclei
#
# > **How to use this notebook:** Read each section, understand the concept, then write the code yourself in the empty cell below. Use the hints as a guide — not a solution.
#
# ---

# %%
# Run this cell first — imports you'll likely need
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from scipy import constants          # physical constants
# from scipy.integrate import solve_ivp  # ODE solver
# from scipy.fft import fft, fftfreq      # Fourier transform
# from sympy import *                      # symbolic math
# import seaborn as sns                    # statistical plots

plt.rcParams['figure.dpi'] = 120
plt.rcParams['font.size'] = 12

# %% [markdown]
# ## Bohr Model — Energy Levels and Spectrum
#
# Energy levels: Eₙ = -13.6/n² eV. Plot energy levels as horizontal lines (n=1 to 6). Draw arrows for transitions belonging to Lyman (to n=1), Balmer (to n=2), and Paschen (to n=3) series.
#
# **Hints:**
# - E = -13.6 / n**2  # for n = 1, 2, 3, ..., 6
# - Draw horizontal lines with plt.axhline(E_n, xmin, xmax)
# - Transitions: for each pair (n_upper, n_lower) draw plt.annotate with arrow
# - Color code: Lyman=UV, Balmer=visible, Paschen=IR

# %%
# Your code here

# %% [markdown]
# ## Hydrogen Emission Spectrum
#
# Compute all transition wavelengths: 1/λ = R_H(1/n₁² - 1/n₂²) where R_H = 1.097e7 m⁻¹. Plot the visible Balmer lines as vertical colored lines on a wavelength axis (like a real spectrum).
#
# **Hints:**
# - For Balmer: n1=2, n2=3,4,5,6,...
# - lam = 1/(R_H*(1/n1**2 - 1/n2**2))
# - Use plt.vlines(lam, 0, 1) with colors matching the wavelength
# - Convert wavelength to RGB: use a lookup or matplotlib colormap

# %%
# Your code here

# %% [markdown]
# ## Radioactive Decay — N(t) and Half-Life
#
# N(t) = N₀ e^(-λt) where λ = ln2/t½. Plot N(t) for 3 isotopes with different half-lives on the same graph (linear and log scale). Mark t = t½, 2t½, 3t½.
#
# **Hints:**
# - t = np.linspace(0, 5*t_half, 500)
# - N = N0 * np.exp(-np.log(2)/t_half * t)
# - Plot on linear scale (top) and log scale (bottom: straight line!)
# - plt.axhline(N0/2) and plt.axvline(t_half)

# %%
# Your code here

# %% [markdown]
# ## Binding Energy per Nucleon
#
# Plot the famous BE/A vs A curve using the Bethe-Weizsäcker (liquid drop) formula:
# BE = a_v·A - a_s·A^(2/3) - a_c·Z(Z-1)/A^(1/3) - a_a·(A-2Z)²/A
# Use: a_v=15.85, a_s=18.34, a_c=0.71, a_a=23.21 MeV. Mark Fe-56 as the peak.
#
# **Hints:**
# - A = np.arange(1, 250)
# - For each A: assume Z ≈ A/2 (approximation)
# - BE_per_A = BE/A
# - plt.plot(A, BE_per_A); mark A=56 (Fe) as peak
# - Show fission (heavy→medium) and fusion (light→medium) both release energy

# %%
# Your code here
