# %% [markdown]
# # Electromagnetic Waves
#
# > **How to use this notebook:** Read each section, understand the concept, then write the code yourself in the empty cell below. Use the hints as a guide — not a solution.
#
# ---

# %%
# Run this cell first — imports you'll likely need
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from scipy import constants          # physical constants
# from scipy.integrate import solve_ivp  # ODE solver
# from scipy.fft import fft, fftfreq      # Fourier transform
# from sympy import *                      # symbolic math
# import seaborn as sns                    # statistical plots

plt.rcParams['figure.dpi'] = 120
plt.rcParams['font.size'] = 12

# %% [markdown]
# ## Visualise an EM Wave in 3D
#
# A plane EM wave propagating in the x-direction:
# E = E₀ cos(kx - ωt) ŷ
# B = B₀ cos(kx - ωt) ẑ
# where B₀ = E₀/c. Plot E and B vectors as quivers along the x-axis at t=0.
#
# **Hints:**
# - x = np.linspace(0, 4*np.pi, 30)  # sample points
# - E_y = E0 * np.cos(k*x)  # E field in y
# - B_z = B0 * np.cos(k*x)  # B field in z
# - Use ax.quiver(x, 0, 0, 0, E_y, 0) for E and ax.quiver(x, 0, 0, 0, 0, B_z) for B in 3D

# %%
# Your code here

# %% [markdown]
# ## The EM Spectrum
#
# Plot the full electromagnetic spectrum on a logarithmic frequency/wavelength axis. Mark the boundaries and names of each region: radio, microwave, infrared, visible, UV, X-ray, gamma.
#
# **Hints:**
# - Use plt.barh() or plt.axvspan() to shade each region
# - x-axis: frequency from 10³ to 10²⁴ Hz (log scale)
# - Use plt.xscale('log')
# - Add text labels with plt.text() for each region

# %%
# Your code here

# %% [markdown]
# ## Intensity and Inverse Square Law
#
# A point source radiates power P uniformly in all directions. Intensity at distance r: I = P/(4πr²). Plot I vs r. Show that doubling the distance quarters the intensity.
#
# **Hints:**
# - r = np.linspace(0.1, 10, 300)  # metres
# - I = P / (4*np.pi*r**2)
# - Mark r=1, 2, 4 and show I drops by factor 4 each time
# - Use plt.loglog() to see the power law as a straight line

# %%
# Your code here

# %% [markdown]
# ## Poynting Vector — Energy Flux
#
# S⃗ = (1/μ₀) E⃗ × B⃗. For a plane wave, |S| = E₀²/(2μ₀c) (time-averaged). Compute the radiation pressure P = S/c. Compare to 1 atm for sunlight (S ≈ 1361 W/m²).
#
# **Hints:**
# - S_avg = E0**2 / (2*mu0*c)
# - P_rad = S_avg / c  # radiation pressure
# - Compute how many m² of solar sail are needed to hover a 1kg object
# - Plot S vs E0 to show quadratic relationship

# %%
# Your code here
