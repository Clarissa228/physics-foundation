# %% [markdown]
# # Wave Optics
#
# > **How to use this notebook:** Read each section, understand the concept, then write the code yourself in the empty cell below. Use the hints as a guide — not a solution.
#
# ---

# %%
# Run this cell first — imports you'll likely need
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from scipy import constants          # physical constants
# from scipy.integrate import solve_ivp  # ODE solver
# from scipy.fft import fft, fftfreq      # Fourier transform
# from sympy import *                      # symbolic math
# import seaborn as sns                    # statistical plots

plt.rcParams['figure.dpi'] = 120
plt.rcParams['font.size'] = 12

# %% [markdown]
# ## Young's Double Slit — Interference Pattern
#
# Intensity: I(θ) = I₀ cos²(πd sinθ / λ). Plot the intensity pattern vs position on a screen placed at distance D from the slits. Show how fringe width Δy = λD/d depends on d and λ.
#
# **Hints:**
# - y = np.linspace(-5e-3, 5e-3, 1000)  # screen position in metres
# - theta = np.arctan(y/D)  # D=1m screen distance
# - I = I0 * np.cos(np.pi*d*np.sin(theta)/lam)**2
# - Try λ=500nm, d=0.5mm; then change d and λ to see effect

# %%
# Your code here

# %% [markdown]
# ## Single Slit Diffraction
#
# Intensity: I(θ) = I₀ (sinc(β/2))² where β = 2πa sinθ/λ, a = slit width.
# Plot the diffraction pattern. Mark the minima at a sinθ = mλ.
#
# **Hints:**
# - beta = np.pi*a*np.sin(theta)/lam
# - I = I0 * (np.sinc(beta/np.pi))**2  # np.sinc is sin(πx)/(πx)
# - Mark minima at sinθ = m*lam/a for m = ±1, ±2, ...
# - Try a = 0.1 mm and a = 0.5 mm to see broadening/narrowing

# %%
# Your code here

# %% [markdown]
# ## Thin Film Interference — Soap Bubble Colours
#
# Light reflected from a thin film of thickness t and refractive index n interferes. For normally incident light: constructive when 2nt = (m+½)λ. Plot reflected intensity vs wavelength for visible light (380–700 nm) for several film thicknesses.
#
# **Hints:**
# - lam = np.linspace(380e-9, 700e-9, 300)  # visible spectrum
# - For thickness t: I_reflected ∝ sin²(2*np.pi*n*t/lam)
# - Plot I vs lam for t = 100nm, 200nm, 500nm
# - The colour corresponds to which wavelengths are enhanced

# %%
# Your code here

# %% [markdown]
# ## Diffraction Grating
#
# A grating with N slits, separation d, gives principal maxima at d sinθ = mλ. Intensity: I = I₀ (sin(Nδ/2)/sin(δ/2))² where δ = 2πd sinθ/λ. Plot the multi-slit pattern for N=2,5,10,50.
#
# **Hints:**
# - delta = 2*np.pi*d*np.sin(theta)/lam
# - I = I0 * (np.sin(N*delta/2)/np.sin(delta/2))**2
# - Watch for division by zero at δ = 0, 2π: use np.where or regularize
# - More slits → sharper peaks (grating spectrometer)

# %%
# Your code here
