# %% [markdown]
# # Ray Optics
#
# > **How to use this notebook:** Read each section, understand the concept, then write the code yourself in the empty cell below. Use the hints as a guide — not a solution.
#
# ---

# %%
# Run this cell first — imports you'll likely need
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from scipy import constants          # physical constants
# from scipy.integrate import solve_ivp  # ODE solver
# from scipy.fft import fft, fftfreq      # Fourier transform
# from sympy import *                      # symbolic math
# import seaborn as sns                    # statistical plots

plt.rcParams['figure.dpi'] = 120
plt.rcParams['font.size'] = 12

# %% [markdown]
# ## Snell's Law and Total Internal Reflection
#
# n₁ sinθ₁ = n₂ sinθ₂. Plot refracted angle θ₂ vs incident angle θ₁ for glass→air (n₁=1.5, n₂=1.0). Find and mark the critical angle θ_c = arcsin(n₂/n₁). Beyond θ_c: TIR.
#
# **Hints:**
# - theta1 = np.linspace(0, np.pi/2, 300)
# - sin_theta2 = (n1/n2)*np.sin(theta1)
# - TIR when sin_theta2 > 1 — handle with np.clip or mask
# - theta_c = np.arcsin(n2/n1); plt.axvline(np.degrees(theta_c))

# %%
# Your code here

# %% [markdown]
# ## Thin Lens — Image Position vs Object Distance
#
# Lens formula: 1/f = 1/v - 1/u (sign convention: real is positive). For a converging lens f=+20cm, plot image distance v vs object distance u from u=-200cm to u=-f (approaching focus).
#
# **Hints:**
# - u = np.linspace(-200, -f-0.1, 500)  # object distances (negative)
# - v = 1/(1/f - 1/u)  # or 1/v = 1/f + 1/u depending on convention
# - v > 0: real image; v < 0: virtual image
# - Also plot magnification m = -v/u

# %%
# Your code here

# %% [markdown]
# ## Ray Diagram for a Convex Lens
#
# Trace three rays from an object through a thin convex lens: (1) parallel to axis → passes through F, (2) through centre → undeviated, (3) through near focal point → emerges parallel. Plot to scale.
#
# **Hints:**
# - Choose object at u=-30cm, f=+20cm — compute image position v
# - Draw the lens as a vertical line with arrows at top and bottom
# - Draw the three principal rays as line segments
# - Mark F and F' on the axis

# %%
# Your code here

# %% [markdown]
# ## Optical Fibre — Total Internal Reflection
#
# Simulate a ray of light propagating inside an optical fibre (core n₁=1.5, cladding n₂=1.45) by reflecting off the walls repeatedly. Plot the zigzag path of the light.
#
# **Hints:**
# - Start with a ray entering at a shallow angle
# - At each wall: check if angle > critical angle (it should be — that's TIR)
# - If TIR: reflect angle; if not: ray escapes
# - Plot x vs y for the bouncing ray inside the fibre

# %%
# Your code here
