# %% [markdown]
# # Magnetic Effects of Current
#
# > **How to use this notebook:** Read each section, understand the concept, then write the code yourself in the empty cell below. Use the hints as a guide — not a solution.
#
# ---

# %%
# Run this cell first — imports you'll likely need
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from scipy import constants          # physical constants
# from scipy.integrate import solve_ivp  # ODE solver
# from scipy.fft import fft, fftfreq      # Fourier transform
# from sympy import *                      # symbolic math
# import seaborn as sns                    # statistical plots

plt.rcParams['figure.dpi'] = 120
plt.rcParams['font.size'] = 12

# %% [markdown]
# ## Magnetic Field of a Long Straight Wire
#
# By Biot-Savart / Ampere's law: B = μ₀I/(2πr). Plot the magnetic field magnitude vs distance. Then plot the 2D field pattern (circular field lines around the wire) using streamplot.
#
# **Hints:**
# - r = np.linspace(0.01, 5, 300)  # metres from wire
# - B = mu0*I/(2*np.pi*r)
# - For 2D: By = -mu0*I*X/(2*np.pi*(X**2+Y**2)), Bx = mu0*I*Y/(2*np.pi*...)
# - plt.streamplot(X, Y, Bx, By)

# %%
# Your code here

# %% [markdown]
# ## Magnetic Field Along Axis of a Current Loop
#
# B(z) = μ₀IR²/(2(R²+z²)^(3/2)) for a loop of radius R carrying current I. Plot B vs z. Then stack multiple loops (solenoid) and show the field is uniform inside.
#
# **Hints:**
# - z = np.linspace(-3*R, 3*R, 500)
# - B_loop = mu0*I*R**2 / (2*(R**2 + z**2)**1.5)
# - For solenoid: sum B contributions from N loops spaced by d
# - Plot shows uniform field in the centre of solenoid

# %%
# Your code here

# %% [markdown]
# ## Charged Particle in a Magnetic Field
#
# A charge q moving with velocity v in field B feels force F = qv×B. For v perpendicular to B, the particle moves in a circle of radius r = mv/(qB). Simulate the circular/helical trajectory.
#
# **Hints:**
# - Use solve_ivp with state [x,y,z,vx,vy,vz]
# - Equations: dvx/dt = (q/m)*(vy*Bz - vz*By) etc.
# - For B along z and initial v in x-y plane: circular motion
# - Add a vz component to get a helix; plot in 3D with ax.plot3D()

# %%
# Your code here

# %% [markdown]
# ## Hysteresis Loop
#
# Sketch a qualitative B-H hysteresis loop for a ferromagnetic material showing: saturation, remanence (B when H=0), coercivity (H when B=0). Use a smooth parametric curve.
#
# **Hints:**
# - Use a sigmoid-like function for the upper and lower branches
# - Upper: B = Bs*tanh((H+Hc)/(Hs)) + offset
# - Lower: B = Bs*tanh((H-Hc)/(Hs)) - offset
# - Mark key points: Br (remanence), Hc (coercivity), Bs (saturation)

# %%
# Your code here
