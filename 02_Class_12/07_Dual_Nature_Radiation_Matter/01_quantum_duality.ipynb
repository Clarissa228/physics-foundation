# %% [markdown]
# # Dual Nature of Radiation and Matter
#
# > **How to use this notebook:** Read each section, understand the concept, then write the code yourself in the empty cell below. Use the hints as a guide — not a solution.
#
# ---

# %%
# Run this cell first — imports you'll likely need
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from scipy import constants          # physical constants
# from scipy.integrate import solve_ivp  # ODE solver
# from scipy.fft import fft, fftfreq      # Fourier transform
# from sympy import *                      # symbolic math
# import seaborn as sns                    # statistical plots

plt.rcParams['figure.dpi'] = 120
plt.rcParams['font.size'] = 12

# %% [markdown]
# ## Photoelectric Effect
#
# Einstein's equation: KE_max = hν - φ, where φ is the work function. Plot KE_max vs frequency ν for several metals (Na: φ=2.3eV, Al: φ=4.1eV, Cu: φ=4.7eV). The slope gives Planck's constant h.
#
# **Hints:**
# - nu = np.linspace(4e14, 15e14, 300)  # Hz
# - For each metal: KE = h*nu - phi (in Joules); zero where negative
# - Plot KE/eV vs nu for all three metals on same graph
# - np.polyfit on one line to extract h from slope

# %%
# Your code here

# %% [markdown]
# ## Stopping Potential vs Frequency
#
# The stopping potential V_s = KE_max/e = (h/e)ν - φ/e. Plot V_s vs ν. Show it is independent of light intensity (change intensity → change current, not V_s).
#
# **Hints:**
# - V_stop = (h/e)*nu - phi/e
# - Plot for two intensities (I₁ and I₂) — lines should overlap!
# - Mark the threshold frequency ν₀ = φ/h where V_stop = 0
# - Extract h/e from slope and compare to 4.136e-15 eV·s

# %%
# Your code here

# %% [markdown]
# ## de Broglie Wavelength
#
# λ = h/p = h/mv. Plot de Broglie wavelength vs kinetic energy for: electron, proton, neutron, and a 0.1g marble. Use log-log axes. Mark atomic scale (1Å = 1e-10 m).
#
# **Hints:**
# - KE = np.logspace(-3, 6, 500) * e_charge  # eV to Joules
# - p = np.sqrt(2*m*KE)
# - lam = h/p
# - plt.loglog(); plt.axhline(1e-10, label='1 Å (atomic scale)')

# %%
# Your code here

# %% [markdown]
# ## Heisenberg Uncertainty — Wave Packet
#
# A Gaussian wave packet: ψ(x) = exp(-x²/4σ²)·exp(ik₀x). Its Fourier transform ψ̃(k) is also Gaussian with width 1/(2σ). Show that Δx·Δp = ℏ/2 at the minimum.
#
# **Hints:**
# - x = np.linspace(-10, 10, 1000)
# - psi = np.exp(-x**2/(4*sigma**2)) * np.exp(1j*k0*x)
# - psi_k = np.fft.fftshift(np.fft.fft(psi))
# - Compute sigma_x and sigma_k; verify sigma_x * sigma_k ≈ 0.5

# %%
# Your code here
