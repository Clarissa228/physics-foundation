# %% [markdown]
# # Electronic Devices
#
# > **How to use this notebook:** Read each section, understand the concept, then write the code yourself in the empty cell below. Use the hints as a guide — not a solution.
#
# ---

# %%
# Run this cell first — imports you'll likely need
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from scipy import constants          # physical constants
# from scipy.integrate import solve_ivp  # ODE solver
# from scipy.fft import fft, fftfreq      # Fourier transform
# from sympy import *                      # symbolic math
# import seaborn as sns                    # statistical plots

plt.rcParams['figure.dpi'] = 120
plt.rcParams['font.size'] = 12

# %% [markdown]
# ## Energy Band Diagram
#
# Draw schematic energy band diagrams for a conductor, semiconductor, and insulator using matplotlib rectangles and lines. Label: valence band, conduction band, band gap (Eg), and Fermi level.
#
# **Hints:**
# - Use plt.fill_between() or patches.Rectangle to draw bands
# - Conductor: bands overlap; Semiconductor: small gap ~1eV; Insulator: large gap ~5eV
# - Draw Fermi level as a dashed horizontal line
# - Add text labels with plt.text()

# %%
# Your code here

# %% [markdown]
# ## Diode I-V Characteristic — Shockley Equation
#
# I = I₀(e^(V/nV_T) - 1) where V_T = kT/e ≈ 26mV at 300K, I₀ = 1×10⁻¹² A, n=1. Plot from V = -2V to +0.8V. Show forward bias, reverse bias, and breakdown region.
#
# **Hints:**
# - V = np.linspace(-2, 0.8, 2000)
# - I = I0*(np.exp(V/(n*Vt)) - 1)
# - Use plt.semilogy(V, abs(I)) to see both regions
# - Add Zener breakdown: when V < -V_Z, I increases steeply

# %%
# Your code here

# %% [markdown]
# ## Half-Wave and Full-Wave Rectification
#
# Apply a sinusoidal AC signal V(t) = Vm sin(2πft). Simulate half-wave rectification (clip negative half) and full-wave rectification (take absolute value). Plot input and both outputs.
#
# **Hints:**
# - t = np.linspace(0, 0.04, 1000)  # 2 cycles at 50 Hz
# - V_ac = Vm * np.sin(2*np.pi*50*t)
# - V_half = np.where(V_ac > 0, V_ac, 0)
# - V_full = np.abs(V_ac)
# - Add a smoothing capacitor effect: use np.maximum.accumulate-like filter

# %%
# Your code here

# %% [markdown]
# ## Logic Gates — Truth Tables
#
# Implement AND, OR, NOT, NAND, NOR, XOR as Python functions operating on binary inputs. Generate and print the complete truth table for each. Then verify De Morgan's laws: NOT(A AND B) = NOT(A) OR NOT(B).
#
# **Hints:**
# - def AND(a, b): return a & b
# - inputs = [(0,0),(0,1),(1,0),(1,1)]
# - Print truth table: for a,b in inputs: print(a, b, AND(a,b))
# - De Morgan: assert all(NAND(a,b) == OR(NOT(a),NOT(b)) for a,b in inputs)

# %%
# Your code here
