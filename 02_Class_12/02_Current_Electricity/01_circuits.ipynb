# %% [markdown]
# # Current Electricity
#
# > **How to use this notebook:** Read each section, understand the concept, then write the code yourself in the empty cell below. Use the hints as a guide — not a solution.
#
# ---

# %%
# Run this cell first — imports you'll likely need
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from scipy import constants          # physical constants
# from scipy.integrate import solve_ivp  # ODE solver
# from scipy.fft import fft, fftfreq      # Fourier transform
# from sympy import *                      # symbolic math
# import seaborn as sns                    # statistical plots

plt.rcParams['figure.dpi'] = 120
plt.rcParams['font.size'] = 12

# %% [markdown]
# ## Ohm's Law — I-V Characteristics
#
# Plot I vs V for: (1) an ohmic resistor (R = 100Ω, straight line), (2) a non-ohmic device (e.g., diode — use Shockley equation I = I₀(e^(V/nVT)-1) with I₀=1e-12 A, n=1, VT=0.026V).
#
# **Hints:**
# - V = np.linspace(-1, 0.8, 1000)
# - I_resistor = V / R
# - I_diode = I0*(np.exp(V/(n*VT)) - 1)
# - Use log scale for y-axis (plt.semilogy) to see both forward and reverse bias

# %%
# Your code here

# %% [markdown]
# ## Kirchhoff's Laws — Solving a Circuit
#
# Set up the KCL/KVL equations for a 3-mesh circuit as a matrix system Ax = b. Solve with numpy.linalg.solve(). Print the branch currents and verify they satisfy Kirchhoff's laws.
#
# **Hints:**
# - Define resistances R1...R6 and EMFs E1, E2
# - Write mesh equations as matrix rows
# - A = np.array([[...],[...],[...]]); b = np.array([...])
# - x = np.linalg.solve(A, b)  # currents I1, I2, I3

# %%
# Your code here

# %% [markdown]
# ## RC Circuit — Charging and Discharging
#
# Charging: V_C(t) = V₀(1 - e^(-t/RC))
# Discharging: V_C(t) = V₀ e^(-t/RC)
# Plot both curves for R=1kΩ, C=100μF. Mark the time constant τ=RC on the graph.
#
# **Hints:**
# - tau = R * C
# - t = np.linspace(0, 5*tau, 500)
# - V_charge = V0*(1 - np.exp(-t/tau))
# - V_discharge = V0*np.exp(-t/tau)
# - Use plt.axvline(tau) and plt.axhline(0.632*V0) to mark τ

# %%
# Your code here

# %% [markdown]
# ## Wheatstone Bridge
#
# The Wheatstone bridge is balanced when R₁/R₂ = R₃/R₄. Plot the galvanometer current Ig vs the unknown resistance Rx as Rx varies around its balance point. Show the sharp null at balance.
#
# **Hints:**
# - Use Kirchhoff's laws to derive Ig = f(R1,R2,R3,Rx,E)
# - Or use a voltage divider approach
# - Rx = np.linspace(0.5*R_balance, 1.5*R_balance, 300)
# - plt.axvline(R_balance) and plt.axhline(0) to mark the null

# %%
# Your code here
