# %% [markdown]
# # Electrostatics
#
# > **How to use this notebook:** Read each section, understand the concept, then write the code yourself in the empty cell below. Use the hints as a guide — not a solution.
#
# ---

# %%
# Run this cell first — imports you'll likely need
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from scipy import constants          # physical constants
# from scipy.integrate import solve_ivp  # ODE solver
# from scipy.fft import fft, fftfreq      # Fourier transform
# from sympy import *                      # symbolic math
# import seaborn as sns                    # statistical plots

plt.rcParams['figure.dpi'] = 120
plt.rcParams['font.size'] = 12

# %% [markdown]
# ## Electric Field Lines and Equipotential Surfaces
#
# For a point charge at the origin, plot the electric field using streamplot (for field lines) and contourf (for equipotential surfaces). Then try a dipole (+q at x=+d, -q at x=-d).
#
# **Hints:**
# - X, Y = np.meshgrid(np.linspace(-5,5,100), np.linspace(-5,5,100))
# - Ex = k*q*X/(X**2+Y**2)**1.5  (sum over charges for dipole)
# - plt.streamplot(X, Y, Ex, Ey, color=|E|, cmap='plasma')
# - plt.contourf(X, Y, V, levels=30, cmap='RdBu') for potential

# %%
# Your code here

# %% [markdown]
# ## Gauss's Law — Numerical Verification
#
# For a point charge q at the origin, verify Gauss's law numerically: ∮ E⃗·dA⃗ = q/ε₀. Compute the surface integral of E over a sphere by summing E·n̂·ΔA over many small patches.
#
# **Hints:**
# - Parametrise sphere: theta, phi = np.meshgrid(angles)
# - E_radial = k*q/R**2 at each point on sphere
# - Surface element dA = R²·sin(theta)·dtheta·dphi
# - Sum E_radial * dA over all patches and compare to q/epsilon0

# %%
# Your code here

# %% [markdown]
# ## Capacitor — Energy and Dielectric
#
# For a parallel plate capacitor: C = ε₀A/d. Plot:
# 1. E field between plates vs applied voltage
# 2. Energy stored U = ½CV² vs voltage
# 3. Effect of inserting a dielectric (C → κC): how does energy change at constant V vs constant Q?
#
# **Hints:**
# - C = epsilon0 * A / d
# - E = V/d; U = 0.5*C*V**2
# - With dielectric: C_new = kappa*C
# - Create two subplots: constant V (V fixed, Q changes) and constant Q (Q fixed, V changes)

# %%
# Your code here

# %% [markdown]
# ## Superposition — Electric Field of Multiple Charges
#
# Place 4 equal charges at the corners of a square. Compute and plot the total electric field at every point in the plane using superposition E_total = ΣEᵢ.
#
# **Hints:**
# - For each charge at position r_i: E_i = k*q*(r-r_i)/|r-r_i|³
# - Sum Ex and Ey components over all charges
# - plt.streamplot() for field lines
# - Mark charge positions with plt.scatter()

# %%
# Your code here
