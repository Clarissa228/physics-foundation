# %% [markdown]
# # Electromagnetic Induction & AC Circuits
#
# > **How to use this notebook:** Read each section, understand the concept, then write the code yourself in the empty cell below. Use the hints as a guide — not a solution.
#
# ---

# %%
# Run this cell first — imports you'll likely need
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from scipy import constants          # physical constants
# from scipy.integrate import solve_ivp  # ODE solver
# from scipy.fft import fft, fftfreq      # Fourier transform
# from sympy import *                      # symbolic math
# import seaborn as sns                    # statistical plots

plt.rcParams['figure.dpi'] = 120
plt.rcParams['font.size'] = 12

# %% [markdown]
# ## Faraday's Law — EMF from a Rotating Coil
#
# A coil of N turns, area A, rotating at angular velocity ω in a field B has:
# Φ(t) = NBA cos(ωt)
# EMF(t) = NBAω sin(ωt)
#
# Plot both Φ and EMF vs time on separate subplots.
#
# **Hints:**
# - omega = 2*np.pi*50  # 50 Hz AC generator
# - Phi = N*B*A*np.cos(omega*t)
# - emf = N*B*A*omega*np.sin(omega*t)  # = -dPhi/dt
# - Use twin y-axis (ax.twinx()) to overlay both

# %%
# Your code here

# %% [markdown]
# ## LCR Series Circuit — Phasor Diagram
#
# For an LCR series circuit at frequency ω:
# - V_R = IR (in phase with I)
# - V_L = IωL (leads I by 90°)
# - V_C = I/ωC (lags I by 90°)
#
# Draw the phasor diagram for a specific ω. Show how V_total is the vector sum.
#
# **Hints:**
# - Draw phasors as arrows using plt.annotate with arrowprops
# - I along x-axis; V_R along x; V_L along +y; V_C along -y
# - V_total = vector sum: V_R + (V_L - V_C)j
# - Show the impedance angle φ = arctan((X_L - X_C)/R)

# %%
# Your code here

# %% [markdown]
# ## Impedance and Resonance
#
# Z = √(R² + (ωL - 1/ωC)²). Plot Z vs frequency f from 1 Hz to 10 kHz for R=100Ω, L=0.1H, C=100μF. Mark the resonance frequency f₀ = 1/(2π√(LC)) where Z is minimum.
#
# **Hints:**
# - f = np.linspace(1, 10000, 5000)
# - omega = 2*np.pi*f
# - Z = np.sqrt(R**2 + (omega*L - 1/(omega*C))**2)
# - plt.semilogx() to see full range; mark f0 with vertical line

# %%
# Your code here

# %% [markdown]
# ## LR Circuit — Current Growth and Decay
#
# When DC voltage V is switched on: I(t) = (V/R)(1 - e^(-t/τ)) where τ = L/R.
# When switched off: I(t) = I₀ e^(-t/τ).
# Plot both for L=1H, R=10Ω.
#
# **Hints:**
# - tau = L/R
# - t = np.linspace(0, 5*tau, 500)
# - I_growth = (V/R)*(1 - np.exp(-t/tau))
# - I_decay = I0*np.exp(-t/tau)
# - Mark τ on plot with dashed lines

# %%
# Your code here
